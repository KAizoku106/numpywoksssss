# %%
import pandas as pd
df= pd.read_csv("C:\\Users\\LENOVO\\Desktop\\Development-jourey\\machinelearningworks\\pands_work\\custormer_behaviours_case_Study\\E-commerce Customer Behavior - Sheet1.csv")
df.head()
# Out:
#    Customer ID  Gender  Age           City Membership Type  Total Spend  \
# 0          101  Female   29       New York            Gold      1120.20
# 1          102    Male   34    Los Angeles          Silver       780.50
# 2          103  Female   43        Chicago          Bronze       510.75
# 3          104    Male   30  San Francisco            Gold      1480.30
# 4          105    Male   27          Miami          Silver       720.40
#
#    Items Purchased  Average Rating  Discount Applied  \
# 0               14             4.6              True
# 1               11             4.1             False
# 2                9             3.4              True
# 3               19             4.7             False
# 4               13             4.0              True
#
#    Days Since Last Purchase Satisfaction Level
# 0                        25          Satisfied
# 1                        18            Neutral
# 2                        42        Unsatisfied
# ...

# %%
df.columns
# Out:
# Index(['Customer ID', 'Gender', 'Age', 'City', 'Membership Type',
#        'Total Spend', 'Items Purchased', 'Average Rating', 'Discount Applied',
#        'Days Since Last Purchase', 'Satisfaction Level'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer ID               350 non-null    int64
#  1   Gender                    350 non-null    object
#  2   Age                       350 non-null    int64
#  3   City                      350 non-null    object
#  4   Membership Type           350 non-null    object
#  5   Total Spend               350 non-null    float64
#  6   Items Purchased           350 non-null    int64
#  7   Average Rating            350 non-null    float64
#  8   Discount Applied          350 non-null    bool
#  9   Days Since Last Purchase  350 non-null    int64
#  10  Satisfaction Level        348 non-null    object
# dtypes: bool(1), float64(2), int64(4), object(4)
# memory usage: 27.8+ KB

# %%
df.isnull().sum()
# Out:
# Customer ID                 0
# Gender                      0
# Age                         0
# City                        0
# Membership Type             0
# Total Spend                 0
# Items Purchased             0
# Average Rating              0
# Discount Applied            0
# Days Since Last Purchase    0
# Satisfaction Level          2
# dtype: int64

# %%
df.groupby("Satisfaction Level")["Average Rating"].mean()
# Out:
# Satisfaction Level
# Neutral        3.655140
# Satisfied      4.646400
# Unsatisfied    3.692241
# Name: Average Rating, dtype: float64

# %%
df.columns
# Out:
# Index(['Customer ID', 'Gender', 'Age', 'City', 'Membership Type',
#        'Total Spend', 'Items Purchased', 'Average Rating', 'Discount Applied',
#        'Days Since Last Purchase', 'Satisfaction Level'],
#       dtype='object')

# %%
df.rename(columns={"Customer Id":"customer_id","Gender":"gender","Age":"age","City":"city","Membeship Type":"membership_type","Total Spend":"total_sped","Items Purchased":"items_purchased","Average Rating":"average_rating","Discount Applied":"discount_applied","Days Since Last Purchase":"days_since_last_purchase","Satisfaction Level":"satisfaction_level"},inplace=True)

# %%
condition= df["average_rating"].apply(lambda x: "Unsatisfied" if x<3.5 else "Neutral" if x>3.5 and x<4.0 else "Satisfied"  )
df["satisfaction_level"].fillna(condition ,inplace=True)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_13168\1686457139.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["satisfaction_level"].fillna(condition ,inplace=True)

# %%
df.isnull().sum()
# Out:
# Customer ID                 0
# gender                      0
# age                         0
# city                        0
# Membership Type             0
# total_sped                  0
# items_purchased             0
# average_rating              0
# discount_applied            0
# days_since_last_purchase    0
# satisfaction_level          0
# dtype: int64

# %%
df["satisfaction_level"].value_counts()
# Out:
# satisfaction_level
# Satisfied      125
# Unsatisfied    118
# Neutral        107
# Name: count, dtype: int64

# %%
df[df["Customer ID"]==172]
# Out:
#     Customer ID  gender  age     city Membership Type  total_sped  \
# 71          172  Female   37  Houston          Bronze       420.8
#
#     items_purchased  average_rating  discount_applied  \
# 71                7             3.1             False
#
#     days_since_last_purchase satisfaction_level
# 71                        21        Unsatisfied

# %%
df["gender"].value_counts()
# Out:
# gender
# Female    175
# Male      175
# Name: count, dtype: int64

# %%
gender_count=df["gender"].value_counts()
import matplotlib.pyplot as plt

plt.plot[gender_count]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 4
#       1 gender_count=df["gender"].value_counts()
#       2 import matplotlib.pyplot as plt
# ----> 4 plt.plot[gender_count]
#
# TypeError: 'function' object is not subscriptable

# %%
#cost_avg_age
df["Age"].mean().__round__()
# Out:
# 34

# %%
#unique memebership
df["Membership Type"].unique()
# Out:
# array(['Gold', 'Silver', 'Bronze'], dtype=object)

# %%
#membership wise count
membership_count= df["Membership Type"].value_counts()
plt.plot(membership_count.index,membership_count.values,color="green",marker="X",linestyle="none")
plt.xlabel("Memebership_type",size=15)
plt.ylabel("count",size=15)
plt.title("Membership Analysis",color= "RED",size="25")
# Out:
# Text(0.5, 1.0, 'Membership Analysis')

# %%
#membership wise total spend
membership_wise_spend =  df.groupby("Membership Type")["total_sped"].sum()
plt.bar(membership_wise_spend.index,membership_wise_spend.values)
plt.xlabel("Membershipo type")
plt.title("membership_wise_spend",size=20,color="green")
plt.ylabel("total spend")
# Out:
# Text(0, 0.5, 'total spend')

# %%
df.columns
# Out:
# Index(['Customer ID', 'gender', 'age', 'city', 'Membership Type', 'total_sped',
#        'items_purchased', 'average_rating', 'discount_applied',
#        'days_since_last_purchase', 'satisfaction_level'],
#       dtype='object')

# %%
df[df["Membership Type"]=="Gold"]
# Out:
#      Customer ID  gender  age           city Membership Type  total_sped  \
# 0            101  Female   29       New York            Gold      1120.2
# 3            104    Male   30  San Francisco            Gold      1480.3
# 6            107  Female   31       New York            Gold      1150.6
# 9            110    Male   28  San Francisco            Gold      1520.1
# 12           113  Female   30       New York            Gold      1200.8
# ..           ...     ...  ...            ...             ...         ...
# 335          436  Female   30       New York            Gold      1200.8
# 338          439    Male   30  San Francisco            Gold      1460.5
# 341          442  Female   31       New York            Gold      1140.6
# 344          445    Male   28  San Francisco            Gold      1480.1
# 347          448  Female   30       New York            Gold      1190.8
#
#      items_purchased  average_rating  discount_applied  \
# ...

# %%
#rating above 4.5
df[df["average_rating"]>4.5]
# Out:
#      Customer ID  gender  age           city Membership Type  total_sped  \
# 0            101  Female   29       New York            Gold      1120.2
# 3            104    Male   30  San Francisco            Gold      1480.3
# 9            110    Male   28  San Francisco            Gold      1520.1
# 15           116    Male   29  San Francisco            Gold      1360.2
# 18           119  Female   32       New York            Gold      1170.3
# ..           ...     ...  ...            ...             ...         ...
# 326          427    Male   30  San Francisco            Gold      1450.5
# 332          433    Male   28  San Francisco            Gold      1490.1
# 335          436  Female   30       New York            Gold      1200.8
# 338          439    Male   30  San Francisco            Gold      1460.5
# 344          445    Male   28  San Francisco            Gold      1480.1
#
#      items_purchased  average_rating  discount_applied  \
# ...

# %%
#customers per city plot
customer_per_city= df["city"].value_counts()
#customer_per_city
plt.bar(customer_per_city.index,customer_per_city.values,color="violet")
df.columns
# Out:
# Index(['Customer ID', 'gender', 'age', 'city', 'Membership Type', 'total_sped',
#        'items_purchased', 'average_rating', 'discount_applied',
#        'days_since_last_purchase', 'satisfaction_level'],
#       dtype='object')

# %%
#city wise total spend[plot]
city_wise_total_spend= df.groupby("city")["total_sped"].sum()
plt.bar(city_wise_total_spend.index,city_wise_total_spend.values,color="green")
plt.xlabel("City")
plt.ylabel("Total spend")
plt.title("City wise total spend",size=20,color="green")
# Out:
# Text(0.5, 1.0, 'City wise total spend')

# %%
city_wise_total_spend= df.groupby("city")["total_sped"].sum()
plt.pie(city_wise_total_spend.values,labels=city_wise_total_spend.index,autopct="%1.1f%%",shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x17873eff4d0>,
# ...
#  [Text(1.0482892953801437, 0.3333009948851073, 'Chicago'),
#   Text(0.6915931686830732, 0.8553939963729618, 'Houston'),
#   Text(-0.10970201354560376, 1.094516088609044, 'Los Angeles'),
#   Text(-0.9428293511093423, 0.5666328746964271, 'Miami'),
#   Text(-0.8991876248554197, -0.633609986748054, 'New York'),
#   Text(0.684663489670123, -0.860950582735577, 'San Francisco')],
#  [Text(0.5717941611164419, 0.18180054266460394, '9.8%'),
#   Text(0.3772326374634944, 0.4665785434761609, '8.8%'),
#   Text(-0.05983746193396568, 0.5970087756049329, '16.1%'),
#   Text(-0.5142705551505503, 0.309072477107142, '13.5%'),
#   Text(-0.49046597719386525, -0.34560544731712034, '23.2%'),
#   Text(0.3734528125473398, -0.4696094087648601, '28.6%')])

# %%
city_wise_average_rating = df.groupby("city")["average_rating"].mean()
city_wise_average_rating
plt.bar(city_wise_average_rating.index,city_wise_average_rating.values)
plt.xlabel("City")
plt.ylabel("Average Rating")
plt.title("city_wise_average_rating")
# Out:
# Text(0.5, 1.0, 'city_wise_average_rating')

# %%
#scatter chart(correlation of two numbers(group numbers))
total_spend_by_each_age = df.groupby("age")["total_sped"].mean()
total_spend_by_each_age
plt.scatter(total_spend_by_each_age.index,total_spend_by_each_age.values,label="Spend")
plt.legend()

# %%
#histogram chart,(group distributions)
plt.hist(df["age"],bins=5,edgecolor="green")
# Out:
# (array([ 69., 106.,  84.,  33.,  58.]),
#  array([26. , 29.4, 32.8, 36.2, 39.6, 43. ]),
#  <BarContainer object of 5 artists>)

# %%
import numpy as np
figures,axes = plt.subplot(2,2)
x=np.array([2,3,4,5,6])
axes[0,0].plot(x,x+2)
axes[0,1].bar(x,x**3)
axes[1,0].hist(x,bins=3,edgecolor="green")
axes[1,1].plot(x,x**5)

# %%
import numpy as np
figures,axes = plt.subplot(2,2)
x=[2,3,4,5,6]
axes[0,0].plot(x,x+2)
axes[0,1].bar(x,x**3)
axes[1,0].hist(x,bins=3,edgecolor="green")
axes[1,1].plot(x,x**5)

# %%
import numpy as np
import matplotlib.pyplot as plt

figure,axes = plt.subplots(2,2)
x=np.array([2,3,4,5,6])
axes[0,0].plot(x,x+2)
axes[0,1].bar(x,x**3)
axes[1,0].hist(x,bins=3,edgecolor="green")
axes[1,1].plot(x,x**5)
