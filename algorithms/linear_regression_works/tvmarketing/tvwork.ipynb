# %%
import pandas as pd
import numpy as np
import seaborn as sns
df = pd.read_csv("C:\\Users\\LENOVO\\Desktop\\Development-jourey\\machinelearningworks\\algorithms\\linear_regression_works\\tvmarketing\\tvmarketing.csv.xls")

# %%
df.head()
# Out:
#       TV  Sales
# 0  230.1   22.1
# 1   44.5   10.4
# 2   17.2    9.3
# 3  151.5   18.5
# 4  180.8   12.9

# %%
df.isnull().sum()
# Out:
# TV       0
# Sales    0
# dtype: int64

# %%
sns.regplot(x=df["TV"],y=df["Sales"])
# Out:
# <Axes: xlabel='TV', ylabel='Sales'>

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,1]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test =train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([0.04652973])

# %%
lr.intercept_
# Out:
# np.float64(7.119638430592953)

# %%
y_pred= lr.predict(x_test)

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error,root_mean_squared_error

print(f"r2_score = {r2_score(y_pred,y_test)*100}")
print(f"mean_absolute_error = {mean_absolute_error(y_pred,y_test)}")
print(f"mean_squared_error = {mean_squared_error(y_pred,y_test)}")
print(f"root_mean_squared_error = {root_mean_squared_error(y_pred,y_test)}")
# Out:
# r2_score = 42.27436514531993
# mean_absolute_error = 2.444420003751042
# mean_squared_error = 10.204654118800956
# root_mean_squared_error = 3.194472431998898
