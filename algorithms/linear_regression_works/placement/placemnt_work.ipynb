# %%
import pandas as pd
import numpy as np
df= pd.read_csv("C:\\Users\\LENOVO\\Desktop\\Development-jourey\\machinelearningworks\\algorithms\\linear_regression_works\\placement\\placement.csv.xls")

# %%
df.head()
# Out:
#    cgpa  placement_exam_marks  placed
# 0  7.19                  26.0       1
# 1  7.46                  38.0       1
# 2  7.54                  40.0       1
# 3  6.42                   8.0       1
# 4  7.23                  17.0       0

# %%
import seaborn as sns

# %%
cl =["cgpa","placement_exam_marks"]
sns.heatmap(df[cl].corr(),annot=True)
# Out:
# <Axes: >
