# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\LENOVO\\Desktop\\Development-jourey\\machinelearningworks\\task\\21_1_26\\world_famous_places_2024.csv")
df.head()
# Out:
#             Place_Name        Country              City  \
# 0         Eiffel Tower         France             Paris
# 1         Times Square  United States     New York City
# 2        Louvre Museum         France             Paris
# 3  Great Wall of China          China  Beijing/Multiple
# 4            Taj Mahal          India              Agra
#
#    Annual_Visitors_Millions                Type UNESCO_World_Heritage  \
# 0                       7.0      Monument/Tower                    No
# 1                      50.0      Urban Landmark                    No
# 2                       8.7              Museum                   Yes
# 3                      10.0   Historic Monument                   Yes
# 4                       7.5  Monument/Mausoleum                   Yes
#
#          Year_Built  Entry_Fee_USD   Best_Visit_Month          Region  \
# 0              1889             35  May-June/Sept-Oct  Western Europe
# ...

# %%
df.tail()
# Out:
#              Place_Name               Country            City  \
# 25         Burj Khalifa  United Arab Emirates           Dubai
# 26              Big Ben        United Kingdom          London
# 27         Tower Bridge        United Kingdom          London
# 28    Buckingham Palace        United Kingdom          London
# 29  Christ the Redeemer                Brazil  Rio de Janeiro
#
#     Annual_Visitors_Millions             Type UNESCO_World_Heritage  \
# 25                       6.0       Skyscraper                    No
# 26                       5.5      Clock Tower                   Yes
# 27                       6.8           Bridge                    No
# 28                      15.0           Palace                    No
# 29                       2.2  Monument/Statue                    No
#
#    Year_Built  Entry_Fee_USD   Best_Visit_Month          Region  \
# 25       2010             45          Nov-March     Middle East
# ...

# %%
df.columns
# Out:
# Index(['Place_Name', 'Country', 'City', 'Annual_Visitors_Millions', 'Type',
#        'UNESCO_World_Heritage', 'Year_Built', 'Entry_Fee_USD',
#        'Best_Visit_Month', 'Region', 'Tourism_Revenue_Million_USD',
#        'Average_Visit_Duration_Hours', 'Famous_For'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Place_Name                      0
# Country                         0
# City                            0
# Annual_Visitors_Millions        0
# Type                            0
# UNESCO_World_Heritage           0
# Year_Built                      0
# Entry_Fee_USD                   0
# Best_Visit_Month                0
# Region                          0
# Tourism_Revenue_Million_USD     0
# Average_Visit_Duration_Hours    0
# Famous_For                      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Place_Name                    30 non-null     object
#  1   Country                       30 non-null     object
#  2   City                          30 non-null     object
#  3   Annual_Visitors_Millions      30 non-null     float64
#  4   Type                          30 non-null     object
#  5   UNESCO_World_Heritage         30 non-null     object
#  6   Year_Built                    30 non-null     object
#  7   Entry_Fee_USD                 30 non-null     int64
#  8   Best_Visit_Month              30 non-null     object
#  9   Region                        30 non-null     object
#  10  Tourism_Revenue_Million_USD   30 non-null     int64
#  11  Average_Visit_Duration_Hours  30 non-null     float64
# ...

# %%
df.count()
# Out:
# Place_Name                      30
# Country                         30
# City                            30
# Annual_Visitors_Millions        30
# Type                            30
# UNESCO_World_Heritage           30
# Year_Built                      30
# Entry_Fee_USD                   30
# Best_Visit_Month                30
# Region                          30
# Tourism_Revenue_Million_USD     30
# Average_Visit_Duration_Hours    30
# Famous_For                      30
# dtype: int64

# %%
#best visit month
df["Best_Visit_Month"].value_counts().idxmax()
# Out:
# 'Apr-May/Sept-Oct'

# %%
#which country have highest number of tourist attraction
df["Country"].value_counts().head(1)
# Out:
# Country
# United States    10
# Name: count, dtype: int64

# %%
#which regions are most repres.ented in the dataset
df["Region"].value_counts().idxmax()
# Out:
# 'North America'

# %%
#most common type of tourist place
df["Type"].value_counts().head(1)
# Out:
# Type
# Historic Monument    3
# Name: count, dtype: int64

# %%
#which place has the highest annual visitors
df.groupby("Place_Name")["Annual_Visitors_Millions"].sum().sort_values(ascending=False).head(1)
# Out:
# Place_Name
# Times Square    50.0
# Name: Annual_Visitors_Millions, dtype: float64

# %%
# do unseco sites  attracs more visitors than non unesco sites
df.groupby("UNESCO_World_Heritage")["Annual_Visitors_Millions"].mean()
# Out:
# UNESCO_World_Heritage
# No     17.830769
# Yes     6.361765
# Name: Annual_Visitors_Millions, dtype: float64
